# %%
# pip install fast-plate-ocr[onnx]

# %%
from fast_plate_ocr import LicensePlateRecognizer
import cv2

img = cv2.imread(r"../image_out/plate_0_0.75.png")

ocr = LicensePlateRecognizer(
    "cct-s-v2-global-model"
)

result = ocr.run(img)

print(result)
# Out:
# [PlatePrediction(plate='TS5330', char_probs=None, region='Finland', region_prob=None)]
